# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e62dc20-8996-43fa-b6ae-f1eaee60cdb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e62dc20-8996-43fa-b6ae-f1eaee60cdb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
print(df.shape)
df.info()
# Out:
# (1470, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Department'].unique())
print(df['JobRole'].unique())
print(df['Attrition'].unique())
print(df['OverTime'].unique())
print(df['BusinessTravel'].unique())
# Out:
# ['Sales' 'Research & Development' 'Human Resources']
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# ['Yes' 'No']
# ['Yes' 'No']
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']

# %%
df[['Age', 'MonthlyIncome', 'YearsAtCompany', 'DistanceFromHome', 'TotalWorkingYears']].describe()
# Out:
#                Age  MonthlyIncome  YearsAtCompany  DistanceFromHome  \
# count  1470.000000    1470.000000     1470.000000       1470.000000
# mean     36.923810    6502.931293        7.008163          9.192517
# std       9.135373    4707.956783        6.126525          8.106864
# min      18.000000    1009.000000        0.000000          1.000000
# 25%      30.000000    2911.000000        3.000000          2.000000
# 50%      36.000000    4919.000000        5.000000          7.000000
# 75%      43.000000    8379.000000        9.000000         14.000000
# max      60.000000   19999.000000       40.000000         29.000000
#
#        TotalWorkingYears
# count        1470.000000
# mean           11.279592
# std             7.780782
# min             0.000000
# 25%             6.000000
# 50%            10.000000
# 75%            15.000000
# max            40.000000

# %%
attrition_rate = round(100 * (df['Attrition'] == 'Yes').sum() / len(df), 2)
print(f"Overall attrition rate: {attrition_rate}%")
# Out:
# Overall attrition rate: 16.12%

# %%
dept_attrition = df.groupby('Department')['Attrition'].apply(
    lambda x: round(100 * (x == 'Yes').sum() / len(x), 2)
)
print(dept_attrition.sort_values(ascending=False))
# Out:
# Department
# Sales                     20.63
# Human Resources           19.05
# Research & Development    13.84
# Name: Attrition, dtype: float64

# %%
ot_attrition = df.groupby('OverTime')['Attrition'].apply(
    lambda x: round(100 * (x == 'Yes').sum() / len(x), 2)
)
print(ot_attrition.sort_values(ascending=False))
# Out:
# OverTime
# Yes    30.53
# No     10.44
# Name: Attrition, dtype: float64

# %%
role_attrition = df.groupby('JobRole')['Attrition'].apply(
    lambda x: round(100 * (x == 'Yes').sum() / len(x), 2)
)
print(role_attrition.sort_values(ascending=False))
# Out:
# JobRole
# Sales Representative         39.76
# Laboratory Technician        23.94
# Human Resources              23.08
# Sales Executive              17.48
# Research Scientist           16.10
# Manufacturing Director        6.90
# Healthcare Representative     6.87
# Manager                       4.90
# Research Director             2.50
# Name: Attrition, dtype: float64

# %%
print(df.groupby('Attrition')[['MonthlyIncome', 'YearsAtCompany']].mean().round(2))
# Out:
#            MonthlyIncome  YearsAtCompany
# Attrition
# No               6832.74            7.37
# Yes              4787.09            5.13
